# %%
import pandas as pd

# %%
res_df = pd.read_csv('data/kaggle-survey-2017/multipleChoiceResponses.csv', encoding='ISO-8859-1', low_memory=False)

# %%
res_df.shape
# Out:
# (16716, 228)

# %%
res_df.iloc[:3, :3]
# Out:
#                                         GenderSelect        Country   Age
# 0  Non-binary, genderqueer, or gender non-conforming            NaN   NaN
# 1                                             Female  United States  30.0
# 2                                               Male         Canada  28.0

# %%
res_df.head()
# Out:
#                                         GenderSelect        Country   Age  \
# 0  Non-binary, genderqueer, or gender non-conforming            NaN   NaN
# 1                                             Female  United States  30.0
# 2                                               Male         Canada  28.0
# 3                                               Male  United States  56.0
# 4                                               Male         Taiwan  38.0
#
#                                     EmploymentStatus StudentStatus  \
# 0                                 Employed full-time           NaN
# 1                 Not employed, but looking for work           NaN
# 2                 Not employed, but looking for work           NaN
# 3  Independent contractor, freelancer, or self-em...           NaN
# 4                                 Employed full-time           NaN
#
#   LearningDataScience CodeWriter CareerSwitcher  \
# 0                 NaN        Yes            NaN
# ...

# %%
res_df['Age'].head()
# Out:
# 0     NaN
# 1    30.0
# 2    28.0
# 3    56.0
# 4    38.0
# Name: Age, dtype: float64

# %%
res_df[['Age', 'Country']].head()
# Out:
#     Age        Country
# 0   NaN            NaN
# 1  30.0  United States
# 2  28.0         Canada
# 3  56.0  United States
# 4  38.0         Taiwan

# %%
res_df.loc[10, 'Country']
# Out:
# 'Russia'

# %%
res_df['Country'].head(10)
# Out:
# 0              NaN
# 1    United States
# 2           Canada
# 3    United States
# 4           Taiwan
# 5           Brazil
# 6    United States
# 7            India
# 8        Australia
# 9           Russia
# Name: Country, dtype: object

# %%
res_df.loc[10:12, ['Age','Country']]
# Out:
#      Age Country
# 10  20.0  Russia
# 11  27.0   India
# 12  26.0  Brazil

# %%
res_df.loc[[True, False, True],[False, True, True]]
# Out:
#   Country   Age
# 0     NaN   NaN
# 2  Canada  28.0

# %%
(res_df['Age'] > 50).head()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# Name: Age, dtype: bool

# %%
res_df.loc[res_df['Age'] > 50].iloc[:3, :5]
# Out:
#    GenderSelect        Country   Age  \
# 3          Male  United States  56.0
# 13         Male    Netherlands  54.0
# 15         Male  United States  58.0
#
#                                      EmploymentStatus StudentStatus
# 3   Independent contractor, freelancer, or self-em...           NaN
# 13                                 Employed full-time           NaN
# 15  Independent contractor, freelancer, or self-em...           NaN

# %%
res_df.where(res_df['Age'] > 50).iloc[:5, :3]
# Out:
#   GenderSelect        Country   Age
# 0          NaN            NaN   NaN
# 1          NaN            NaN   NaN
# 2          NaN            NaN   NaN
# 3         Male  United States  56.0
# 4          NaN            NaN   NaN

# %%
groupby_country = res_df.groupby('Country')

# %%
groupby_country

# %%
groupby_country.count()
# Out:
#                              GenderSelect   Age  EmploymentStatus  \
# Country
# Argentina                              92    92                92
# Australia                             421   409               421
# Belarus                                54    54                54
# Belgium                                91    91                91
# Brazil                                465   464               465
# Canada                                440   431               440
# Chile                                  51    51                51
# Colombia                              113   113               113
# Czech Republic                         53    53                53
# Denmark                                77    78                78
# Egypt                                  66    66                66
# Finland                                67    67                67
# France                                442   438               442
# ...

# %%
groupby_country = res_df.groupby('Country')

# %%
groupby_country

# %%
groupby_country.count().iloc[:3, :4]
# Out:
#            GenderSelect  Age  EmploymentStatus  StudentStatus
# Country
# Argentina            92   92                92              3
# Australia           421  409               421             23
# Belarus              54   54                54              2

# %%
groupby_country.Country

# %%
s = lambda x : print(x) in [1,2,3]
